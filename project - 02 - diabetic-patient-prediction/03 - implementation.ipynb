# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv("cleaned_data.csv")

# %%
ds.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Lets divide in independent(X) and dependent(y)
X = ds[['Pregnancies', 'Glucose', 'BloodPressure','SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']]
y = ds[["Outcome"]]

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#x = pd.DataFrame(sc.fit_transform(x), columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = pd.DataFrame(sc.fit_transform(x), columns=x.columns)

# %%
from sklearn.linear_model import LogisticRegression
cls = LogisticRegression()
cls.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = cls.predict(x_test)
y_pred = pd.DataFrame(y_pred, columns = ["Result"])

# %%
result = pd.concat([y_test.reset_index(drop = True), y_pred.reset_index(drop = True)], axis = 1)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(result["Outcome"], result["Result"])
score = accuracy_score(result["Outcome"], result["Result"])
score
# Out:
# 0.74

# %%
from sklearn .pipeline import make_pipeline
pipe = make_pipeline(sc, cls)

# %%
data = [[4, 145, 88, 32, 180, 37.5, 0.9, 55]]
myinput = pd.DataFrame(data = data, columns = columns)
result = pipe.predict(myinput)
result
# Out:
# array([1])

# %%
import pickle as pkl
pkl.dump(sc, open("scaler.pkl","wb+"))
pkl.dump(cls, open("model.pkl", "wb+"))

# %%
from sklearn.pipeline import make_pipeline
pipe = make_pipeline(sc, cls)
data = [[4, 145, 88, 32, 180, 37.5, 0.9, 55]]
myinput = pd.DataFrame(data = data, columns = columns)
result = pipe.predict(myinput)
result
# Out:
# array([1])

# %%
pkl.dump(pipe, open("pipe.pkl", "wb+"))
